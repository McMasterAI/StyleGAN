# %% [markdown]
# # Style GAN

# %% [markdown]
# This notebook implements a Style Transfer GAN that generates paintings.

# %% [markdown]
# # Data Loading

# %% [markdown]
# First, be sure to go to your Kaggle profile and create an API token. Make sure it's in your .kaggle folder. Also, you must join this competition to accept the terms and conditions before you can download the data: https://www.kaggle.com/c/gan-getting-started/data

# %%
if (input("Are you running in collab? (y/n): ") == 'y'):
    print("Running Collab imports")
    # Upload Kaggle.json
    from google.colab import files 
    files.upload()
    ! mkdir ~/.kaggle
    ! cp kaggle.json ~/.kaggle/
    ! chmod 600 ~/.kaggle/kaggle.json
else:
    print("Ignoring collab code")
# Out:
# Are you running in collab? (y/n): y
# Running Collab imports
#      <input type="file" id="files-e8fd5285-531b-46e5-a54e-efce31f01595" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8fd5285-531b-46e5-a54e-efce31f01595">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
! pip install --user tensorflow-addons==0.8.3 
! pip install --user tensorflow==2.2.0-rc3
# Out:
# Collecting tensorflow-addons==0.8.3
#   Downloading https://files.pythonhosted.org/packages/3d/38/6405e8a540bfc4f687fce91177022ace45490e70ca1c2d503ea6de2d0c9c/tensorflow_addons-0.8.3-cp37-cp37m-manylinux2010_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 7.2MB/s
# Requirement already satisfied: typeguard in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons==0.8.3) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.8.3
# Collecting tensorflow==2.2.0-rc3
#   Downloading https://files.pythonhosted.org/packages/05/11/e1430cf2d2196a67c42bb761fa19e46dc08de52abfe90fbdad390eb41dca/tensorflow-2.2.0rc3-cp37-cp37m-manylinux2010_x86_64.whl (516.2MB)
#      |████████████████████████████████| 516.2MB 28kB/s
# Collecting tensorflow-estimator<2.3.0,>=2.2.0rc0
#   Downloading https://files.pythonhosted.org/packages/a4/f5/926ae53d6a226ec0fda5208e0e581cffed895ccc89e36ba76a8e60895b78/tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454kB)
#      |████████████████████████████████| 460kB 36.0MB/s
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (0.2.0)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/1d/74/0a6fcb206dcc72a6da9a62dd81784bfdbff5fedb099982861dc2219014fb/tensorboard-2.2.2-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 39.9MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (3.12.4)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (1.32.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (1.1.2)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (0.3.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (0.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (1.1.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (1.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (3.3.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (1.19.5)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (1.12.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (0.36.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (1.15.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0-rc3) (1.6.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (2.23.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (1.28.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (54.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (0.4.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (1.24.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (4.7.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (3.7.4.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0-rc3) (3.1.0)
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow
#   WARNING: The script tensorboard is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed tensorboard-2.2.2 tensorflow-2.2.0rc3 tensorflow-estimator-2.2.0

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
import kaggle
from kaggle.api.kaggle_api_extended import KaggleApi

import zipfile
import os

import time
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

AUTOTUNE = tf.data.experimental.AUTOTUNE
    
print(tf.__version__)
# Out:
# Number of replicas: 1
# 2.2.0-rc3

# %%
api = KaggleApi()
api.authenticate()
if (not os.path.exists('./imgdata')):
    api.competition_download_files('gan-getting-started', path='./imgdata')
    print("Download complete!")
# Out:
# Download complete!

# %%
# Unzip the folder
print("Unzipping images...")
zp = zipfile.ZipFile("./imgdata/gan-getting-started.zip", "r")
zp.extractall("./imgdata/gan-getting-started")
zp.close()
print("Unzipped!")
# Out:
# Unzipping images...
# Unzipped!

# %%
IMG_PATH = "imgdata/gan-getting-started"

# %%
MONET_FILENAMES = tf.io.gfile.glob(str(IMG_PATH + '/monet_tfrec/*.tfrec'))
print('Monet TFRecord Files:', len(MONET_FILENAMES))

PHOTO_FILENAMES = tf.io.gfile.glob(str(IMG_PATH + '/photo_tfrec/*.tfrec'))
print('Photo TFRecord Files:', len(PHOTO_FILENAMES))
# Out:
# Monet TFRecord Files: 5
# Photo TFRecord Files: 20

# %%
IMAGE_SIZE = [256, 256]

def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = (tf.cast(image, tf.float32) / 127.5) - 1
    image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

def read_tfrecord(example):
    tfrecord_format = {
        "image_name": tf.io.FixedLenFeature([], tf.string),
        "image": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_image(example['image'])
    return image

# %%
def load_dataset(filenames, labeled=True, ordered=False):
    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.map(read_tfrecord, num_parallel_calls=AUTOTUNE)
    return dataset

# %%
monet_ds = load_dataset(MONET_FILENAMES, labeled=True).batch(1)
photo_ds = load_dataset(PHOTO_FILENAMES, labeled=True).batch(1)

# %%
example_monet = next(iter(monet_ds))
example_photo = next(iter(photo_ds))

# %%
plt.subplot(121)
plt.title('Photo')
plt.imshow(example_photo[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title('Monet')
plt.imshow(example_monet[0] * 0.5 + 0.5)

# %%
photo_ds._batch_size
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=1>

# %% [markdown]
# ## Building the Generator

# %%
OUTPUT_CHANNELS = 3

def downsample(filters, size, apply_instancenorm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

    if apply_instancenorm:
        result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    result.add(layers.LeakyReLU())

    return result

# %%
def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2DTranspose(filters, size, strides=2,
                                      padding='same',
                                      kernel_initializer=initializer,
                                      use_bias=False))

    result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    if apply_dropout:
        result.add(layers.Dropout(0.5))

    result.add(layers.ReLU())

    return result

# %%
def Generator():
    inputs = layers.Input(shape=[256,256,3])

    # bs = batch size
    down_stack = [
        downsample(64, 4, apply_instancenorm=False), # (bs, 128, 128, 64)
        downsample(128, 4), # (bs, 64, 64, 128)
        downsample(256, 4), # (bs, 32, 32, 256)
        downsample(512, 4), # (bs, 16, 16, 512)
        downsample(512, 4), # (bs, 8, 8, 512)
        downsample(512, 4), # (bs, 4, 4, 512)
        downsample(512, 4), # (bs, 2, 2, 512)
        downsample(512, 4), # (bs, 1, 1, 512)
    ]

    up_stack = [
        upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
        upsample(512, 4), # (bs, 16, 16, 1024)
        upsample(256, 4), # (bs, 32, 32, 512)
        upsample(128, 4), # (bs, 64, 64, 256)
        upsample(64, 4), # (bs, 128, 128, 128)
    ]

    initializer = tf.random_normal_initializer(0., 0.02)
    last = layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                  strides=2,
                                  padding='same',
                                  kernel_initializer=initializer,
                                  activation='tanh') # (bs, 256, 256, 3)

    x = inputs

    # Downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)

    skips = reversed(skips[:-1])

    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = layers.Concatenate()([x, skip])

    x = last(x)

    return keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# ## Building the Discriminator

# %%
def Discriminator():

    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    inp = layers.Input(shape=[256, 256, 3], name='input_image')

    x = inp

    down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
    down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
    down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

    zero_pad1 = layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = layers.Conv2D(512, 4, strides=1,
                         kernel_initializer=initializer,
                         use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

    norm1 = tfa.layers.InstanceNormalization(gamma_initializer=gamma_init)(conv)

    leaky_relu = layers.LeakyReLU()(norm1)

    zero_pad2 = layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

    last = layers.Conv2D(1, 4, strides=1,
                         kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

    return tf.keras.Model(inputs=inp, outputs=last)

# %%
with strategy.scope():
    monet_generator = Generator() # transforms photos to Monet-esque paintings
    photo_generator = Generator() # transforms Monet paintings to be more like photos

    monet_discriminator = Discriminator() # differentiates real Monet paintings and generated Monet paintings
    photo_discriminator = Discriminator() # differentiates real photos and generated photos

# %%
to_monet = monet_generator(example_photo)

plt.subplot(1, 2, 1)
plt.title("Original Photo")
plt.imshow(example_photo[0] * 0.5 + 0.5)

plt.subplot(1, 2, 2)
plt.title("Monet-esque Photo")
plt.imshow(to_monet[0] * 0.5 + 0.5)
plt.show()

# %% [markdown]
# ## Building the CycleGAN Model

# %%
class CycleGan(keras.Model):
    
    def __init__(
        self,
        monet_generator,
        photo_generator,
        monet_discriminator,
        photo_discriminator,
        lambda_cycle=10,
    ):
        super(CycleGan, self).__init__()
        self.m_gen = monet_generator
        self.p_gen = photo_generator
        self.m_disc = monet_discriminator
        self.p_disc = photo_discriminator
        self.lambda_cycle = lambda_cycle
        
    def compile(
        self,
        m_gen_optimizer,
        p_gen_optimizer,
        m_disc_optimizer,
        p_disc_optimizer,
        gen_loss_fn,
        disc_loss_fn,
        cycle_loss_fn,
        identity_loss_fn
    ):
        super(CycleGan, self).compile()
        self.m_gen_optimizer = m_gen_optimizer
        self.p_gen_optimizer = p_gen_optimizer
        self.m_disc_optimizer = m_disc_optimizer
        self.p_disc_optimizer = p_disc_optimizer
        self.gen_loss_fn = gen_loss_fn
        self.disc_loss_fn = disc_loss_fn
        self.cycle_loss_fn = cycle_loss_fn
        self.identity_loss_fn = identity_loss_fn

    def train_step(self, batch_data):
        real_monet, real_photo = batch_data
      
        with tf.GradientTape(persistent=True) as tape:
            # photo to monet back to photo
            fake_monet = self.m_gen(real_photo, training=True)
            cycled_photo = self.p_gen(fake_monet, training=True)

            # monet to photo back to monet
            fake_photo = self.p_gen(real_monet, training=True)
            cycled_monet = self.m_gen(fake_photo, training=True)

            # generating itself
            same_monet = self.m_gen(real_monet, training=True)
            same_photo = self.p_gen(real_photo, training=True)

            #monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            #loss.append(tf.reduce_sum(monet_gen_loss).numpy())

            current = [real_monet, cycled_monet, real_photo, cycled_photo, same_monet, same_photo]
            image_pool.append(current)

            if len(image_pool) > 150:
              image_pool.pop(0)

            #if len(loss) > 160:
              #loss.pop(loss.index(min(loss)))

            # discriminator used to check, inputing real images
            disc_real_monet = self.m_disc(real_monet, training=True)
            disc_real_photo = self.p_disc(real_photo, training=True)

            # discriminator used to check, inputing fake images
            disc_fake_monet = self.m_disc(fake_monet, training=True)
            disc_fake_photo = self.p_disc(fake_photo, training=True)

            # evaluates generator loss
            monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            photo_gen_loss = self.gen_loss_fn(disc_fake_photo)

            # evaluates total cycle consistency loss
            total_cycle_loss = self.cycle_loss_fn(real_monet, cycled_monet, self.lambda_cycle) + self.cycle_loss_fn(real_photo, cycled_photo, self.lambda_cycle)

            # evaluates total generator loss
            total_monet_gen_loss = monet_gen_loss + total_cycle_loss + self.identity_loss_fn(real_monet, same_monet, self.lambda_cycle)
            total_photo_gen_loss = photo_gen_loss + total_cycle_loss + self.identity_loss_fn(real_photo, same_photo, self.lambda_cycle)
            
            p = random.uniform(0,1)
            if p > 0.5:
              [real_monet, cycled_monet, real_photo, cycled_photo, same_monet, same_photo] = current
              
            else:

              random_id = random.randint(0, len(image_pool)-1)
              #idx = loss.index(max(loss))
              temp = image_pool[random_id]
              [real_monet, cycled_monet, real_photo, cycled_photo, same_monet, same_photo] = temp

            # discriminator used to check, inputing real images
            disc_real_monet = self.m_disc(real_monet, training=True)
            disc_real_photo = self.p_disc(real_photo, training=True)

            # discriminator used to check, inputing fake images
            disc_fake_monet = self.m_disc(fake_monet, training=True)
            disc_fake_photo = self.p_disc(fake_photo, training=True)
              
            # evaluates discriminator loss
            monet_disc_loss = self.disc_loss_fn(disc_real_monet, disc_fake_monet)
            photo_disc_loss = self.disc_loss_fn(disc_real_photo, disc_fake_photo)


        # Calculate the gradients for generator and discriminator
        monet_generator_gradients = tape.gradient(total_monet_gen_loss,
                                                  self.m_gen.trainable_variables)
        photo_generator_gradients = tape.gradient(total_photo_gen_loss,
                                                  self.p_gen.trainable_variables)

        monet_discriminator_gradients = tape.gradient(monet_disc_loss,
                                                      self.m_disc.trainable_variables)
        photo_discriminator_gradients = tape.gradient(photo_disc_loss,
                                                      self.p_disc.trainable_variables)

        # Apply the gradients to the optimizer
        self.m_gen_optimizer.apply_gradients(zip(monet_generator_gradients,
                                                 self.m_gen.trainable_variables))

        self.p_gen_optimizer.apply_gradients(zip(photo_generator_gradients,
                                                 self.p_gen.trainable_variables))

        self.m_disc_optimizer.apply_gradients(zip(monet_discriminator_gradients,
                                                  self.m_disc.trainable_variables))

        self.p_disc_optimizer.apply_gradients(zip(photo_discriminator_gradients,
                                                  self.p_disc.trainable_variables))
        
        return {
            "monet_gen_loss": total_monet_gen_loss,
            "photo_gen_loss": total_photo_gen_loss,
            "monet_disc_loss": monet_disc_loss,
            "photo_disc_loss": photo_disc_loss
        }

# %% [markdown]
# ## Define Loss Functions

# %%
with strategy.scope():
    
    def discriminator_loss(real, generated):
        real_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(real), real)

        generated_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.zeros_like(generated), generated)

        total_disc_loss = real_loss + generated_loss

        return total_disc_loss * 0.5

# %%
with strategy.scope():
    
    def generator_loss(generated):
        return tf.keras.losses.BinaryCrossentropy(from_logits=True, 
                                    reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(generated),generated)

# %%
#We want our original photo and the twice transformed photo to be similar to one another. 
#Thus, we can calculate the cycle consistency loss be finding the average of their difference.

with strategy.scope():
    
    def calc_cycle_loss(real_image, cycled_image, LAMBDA):
        loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))

        return LAMBDA * loss1

# %%
with strategy.scope():
    
    def identity_loss(real_image, same_image, LAMBDA):
        loss = tf.reduce_mean(tf.abs(real_image - same_image))
        return LAMBDA * 0.5 * loss

# %% [markdown]
# # GAN-Q-Learning

# %%
import utils
import gym

class CycleGan(keras.Model):
    
    def __init__(
        self,
        monet_generator,
        photo_generator,
        monet_discriminator,
        photo_discriminator,
        lambda_cycle=10,
        env,
        episodes,
        buffer_size,
        reward_discount,
        learning_rate = 0.0005,
        n_dis = 1,
        n_gen = 1,
        log_dir=None
    ):
        super(CycleGan, self).__init__()
        self.m_gen = monet_generator
        self.p_gen = photo_generator
        self.m_disc = monet_discriminator
        self.p_disc = photo_discriminator
        self.lambda_cycle = lambda_cycle
        self.env = gym.make('CartPole-v0'),
        self.episodes = 300,
        self.buffer_size = 160,
        self.reward_discount = 0.99

        
    def compile(
        self,
        m_gen_optimizer,
        p_gen_optimizer,
        m_disc_optimizer,
        p_disc_optimizer,
        gen_loss_fn,
        disc_loss_fn,
        cycle_loss_fn,
        identity_loss_fn
    ):
        super(CycleGan, self).compile()
        self.m_gen_optimizer = m_gen_optimizer
        self.p_gen_optimizer = p_gen_optimizer
        self.m_disc_optimizer = m_disc_optimizer
        self.p_disc_optimizer = p_disc_optimizer
        self.gen_loss_fn = gen_loss_fn
        self.disc_loss_fn = disc_loss_fn
        self.cycle_loss_fn = cycle_loss_fn
        self.identity_loss_fn = identity_loss_fn

    z_shape = monet_generator.input_shape.as_list()[1:]

    assert sess = Generator.sess
    assert sess = Discriminator.sess

    last_obs = env.reset()

    buffer = utils.ReplayBuffer(buffer_size, 1)

    sess.run(tf.global_variables_initializer())
    
    def train_step(self, batch_data):
        real_monet, real_photo = batch_data
      
        with tf.GradientTape(persistent=True) as tape:
            # photo to monet back to photo
            fake_monet = self.m_gen(real_photo, training=True)
            cycled_photo = self.p_gen(fake_monet, training=True)

            # monet to photo back to monet
            fake_photo = self.p_gen(real_monet, training=True)
            cycled_monet = self.m_gen(fake_photo, training=True)

            # generating itself
            same_monet = self.m_gen(real_monet, training=True)
            same_photo = self.p_gen(real_photo, training=True)

            # discriminator used to check, inputing real images
            disc_real_monet = self.m_disc(real_monet, training=True)
            disc_real_photo = self.p_disc(real_photo, training=True)

            # discriminator used to check, inputing fake images
            disc_fake_monet = self.m_disc(fake_monet, training=True)
            disc_fake_photo = self.p_disc(fake_photo, training=True)

            monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            loss.append(tf.reduce_sum(monet_gen_loss).numpy())

            current = [real_monet, cycled_monet, real_photo, cycled_photo, same_monet, same_photo]
            image_pool.append(current)

            if len(image_pool) > 160:
              image_pool.pop(loss.index(min(loss)))

            if len(loss) > 160:
              loss.pop(loss.index(min(loss)))
            
            p = random.uniform(0,1)
            if p > 0.5:
              [real_monet, cycled_monet, real_photo, cycled_photo, same_monet, same_photo] = current
              
            else:

              #random_id = random.randint(0, len(image_pool)-1)
              idx = loss.index(max(loss))
              temp = image_pool[idx]
              [real_monet, cycled_monet, real_photo, cycled_photo, same_monet, same_photo] = temp
              
              # discriminator used to check, inputing real images
              disc_real_monet = self.m_disc(real_monet, training=True)
              disc_real_photo = self.p_disc(real_photo, training=True)

              # discriminator used to check, inputing fake images
              disc_fake_monet = self.m_disc(fake_monet, training=True)
              disc_fake_photo = self.p_disc(fake_photo, training=True)

            # evaluates generator loss
            monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            photo_gen_loss = self.gen_loss_fn(disc_fake_photo)

            # evaluates total cycle consistency loss
            total_cycle_loss = self.cycle_loss_fn(real_monet, cycled_monet, self.lambda_cycle) + self.cycle_loss_fn(real_photo, cycled_photo, self.lambda_cycle)

            # evaluates total generator loss
            total_monet_gen_loss = monet_gen_loss + total_cycle_loss + self.identity_loss_fn(real_monet, same_monet, self.lambda_cycle)
            total_photo_gen_loss = photo_gen_loss + total_cycle_loss + self.identity_loss_fn(real_photo, same_photo, self.lambda_cycle)

            # evaluates discriminator loss
            monet_disc_loss = self.disc_loss_fn(disc_real_monet, disc_fake_monet)
            photo_disc_loss = self.disc_loss_fn(disc_real_photo, disc_fake_photo)


        # Calculate the gradients for generator and discriminator
        monet_generator_gradients = tape.gradient(total_monet_gen_loss,
                                                  self.m_gen.trainable_variables)
        photo_generator_gradients = tape.gradient(total_photo_gen_loss,
                                                  self.p_gen.trainable_variables)

        monet_discriminator_gradients = tape.gradient(monet_disc_loss,
                                                      self.m_disc.trainable_variables)
        photo_discriminator_gradients = tape.gradient(photo_disc_loss,
                                                      self.p_disc.trainable_variables)

        # Apply the gradients to the optimizer
        self.m_gen_optimizer.apply_gradients(zip(monet_generator_gradients,
                                                 self.m_gen.trainable_variables))

        self.p_gen_optimizer.apply_gradients(zip(photo_generator_gradients,
                                                 self.p_gen.trainable_variables))

        self.m_disc_optimizer.apply_gradients(zip(monet_discriminator_gradients,
                                                  self.m_disc.trainable_variables))

        self.p_disc_optimizer.apply_gradients(zip(photo_discriminator_gradients,
                                                  self.p_disc.trainable_variables))
        


        return {
            "monet_gen_loss": total_monet_gen_loss,
            "photo_gen_loss": total_photo_gen_loss,
            "monet_disc_loss": monet_disc_loss,
            "photo_disc_loss": photo_disc_loss
        }

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Train the CycleGAN

# %%
with strategy.scope():
    
    monet_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

    monet_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
with strategy.scope():
    
    cycle_gan_model = CycleGan(
        monet_generator, photo_generator, monet_discriminator, photo_discriminator
    )

    cycle_gan_model.compile(
        m_gen_optimizer = monet_generator_optimizer,
        p_gen_optimizer = photo_generator_optimizer,
        m_disc_optimizer = monet_discriminator_optimizer,
        p_disc_optimizer = photo_discriminator_optimizer,
        gen_loss_fn = generator_loss,
        disc_loss_fn = discriminator_loss,
        cycle_loss_fn = calc_cycle_loss,
        identity_loss_fn = identity_loss
    )

# %%
import random
image_pool = []
loss = []
tf.config.experimental_run_functions_eagerly(True)

class TimeHistory(keras.callbacks.Callback):

  def on_train_begin(self, logs={}):

    self.times = []

  def on_epoch_begin(self, epoch, logs={}):

    self.epoch_time_start = time.time()

  def on_epoch_end(self, epoch, logs={}):

    self.times.append(time.time() - self.epoch_time_start)

time_callback = TimeHistory()
# Get model weights to save
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
save_weights_only=True,
verbose=1)
# Checkpoints can be reloaded and used in the model as explained here:
# https://www.tensorflow.org/tutorials/keras/save_and_load

history = cycle_gan_model.fit(
tf.data.Dataset.zip((monet_ds, photo_ds)),
epochs=25,
callbacks=[time_callback, cp_callback]
)
# Out:
# Epoch 1/25
#     300/Unknown - 330s 1s/step - monet_gen_loss: 3.3176 - photo_gen_loss: 3.4179 - monet_disc_loss: 0.6455 - photo_disc_loss: 0.6072
# Epoch 00001: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 335s 1s/step - monet_gen_loss: 3.3172 - photo_gen_loss: 3.4163 - monet_disc_loss: 0.6448 - photo_disc_loss: 0.6065
# Epoch 2/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3.2033 - photo_gen_loss: 3.3099 - monet_disc_loss: 0.6315 - photo_disc_loss: 0.6081
# Epoch 00002: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 337s 1s/step - monet_gen_loss: 3.2017 - photo_gen_loss: 3.3087 - monet_disc_loss: 0.6312 - photo_disc_loss: 0.6085
# Epoch 3/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3.1562 - photo_gen_loss: 3.2497 - monet_disc_loss: 0.6261 - photo_disc_loss: 0.6087
# Epoch 00003: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 334s 1s/step - monet_gen_loss: 3.1556 - photo_gen_loss: 3.2478 - monet_disc_loss: 0.6258 - photo_disc_loss: 0.6083
# Epoch 4/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3.1171 - photo_gen_loss: 3.2305 - monet_disc_loss: 0.6277 - photo_disc_loss: 0.5957
# Epoch 00004: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 335s 1s/step - monet_gen_loss: 3.1168 - photo_gen_loss: 3.2284 - monet_disc_loss: 0.6278 - photo_disc_loss: 0.5953
# Epoch 5/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3.1061 - photo_gen_loss: 3.2024 - monet_disc_loss: 0.6134 - photo_disc_loss: 0.6106
# Epoch 00005: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 329s 1s/step - monet_gen_loss: 3.1065 - photo_gen_loss: 3.2002 - monet_disc_loss: 0.6126 - photo_disc_loss: 0.6112
# Epoch 6/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3.0563 - photo_gen_loss: 3.1522 - monet_disc_loss: 0.6248 - photo_disc_loss: 0.6054
# Epoch 00006: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 330s 1s/step - monet_gen_loss: 3.0554 - photo_gen_loss: 3.1509 - monet_disc_loss: 0.6248 - photo_disc_loss: 0.6049
# Epoch 7/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.9524 - photo_gen_loss: 3.0744 - monet_disc_loss: 0.6278 - photo_disc_loss: 0.6109
# Epoch 00007: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 330s 1s/step - monet_gen_loss: 2.9527 - photo_gen_loss: 3.0719 - monet_disc_loss: 0.6278 - photo_disc_loss: 0.6109
# Epoch 8/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.9320 - photo_gen_loss: 3.0595 - monet_disc_loss: 0.6250 - photo_disc_loss: 0.6096
# Epoch 00008: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 331s 1s/step - monet_gen_loss: 2.9330 - photo_gen_loss: 3.0575 - monet_disc_loss: 0.6251 - photo_disc_loss: 0.6094
# Epoch 9/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.9349 - photo_gen_loss: 2.9986 - monet_disc_loss: 0.6207 - photo_disc_loss: 0.6066
# Epoch 00009: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 327s 1s/step - monet_gen_loss: 2.9341 - photo_gen_loss: 2.9963 - monet_disc_loss: 0.6207 - photo_disc_loss: 0.6064
# Epoch 10/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.9168 - photo_gen_loss: 3.0087 - monet_disc_loss: 0.6117 - photo_disc_loss: 0.6012
# Epoch 00010: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 331s 1s/step - monet_gen_loss: 2.9164 - photo_gen_loss: 3.0078 - monet_disc_loss: 0.6112 - photo_disc_loss: 0.6020
# Epoch 11/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.8537 - photo_gen_loss: 2.9318 - monet_disc_loss: 0.6188 - photo_disc_loss: 0.6165
# Epoch 00011: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 329s 1s/step - monet_gen_loss: 2.8554 - photo_gen_loss: 2.9300 - monet_disc_loss: 0.6189 - photo_disc_loss: 0.6166
# Epoch 12/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.8525 - photo_gen_loss: 2.9282 - monet_disc_loss: 0.6165 - photo_disc_loss: 0.6045
# Epoch 00012: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 329s 1s/step - monet_gen_loss: 2.8529 - photo_gen_loss: 2.9260 - monet_disc_loss: 0.6167 - photo_disc_loss: 0.6052
# Epoch 13/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.8114 - photo_gen_loss: 2.8746 - monet_disc_loss: 0.6292 - photo_disc_loss: 0.6131
# Epoch 00013: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 330s 1s/step - monet_gen_loss: 2.8111 - photo_gen_loss: 2.8723 - monet_disc_loss: 0.6296 - photo_disc_loss: 0.6129
# Epoch 14/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.7964 - photo_gen_loss: 2.8373 - monet_disc_loss: 0.6230 - photo_disc_loss: 0.6135
# Epoch 00014: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 335s 1s/step - monet_gen_loss: 2.7963 - photo_gen_loss: 2.8353 - monet_disc_loss: 0.6231 - photo_disc_loss: 0.6137
# Epoch 15/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.7646 - photo_gen_loss: 2.7622 - monet_disc_loss: 0.6200 - photo_disc_loss: 0.6272
# Epoch 00015: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 335s 1s/step - monet_gen_loss: 2.7648 - photo_gen_loss: 2.7604 - monet_disc_loss: 0.6201 - photo_disc_loss: 0.6270
# Epoch 16/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.7010 - photo_gen_loss: 2.7803 - monet_disc_loss: 0.6340 - photo_disc_loss: 0.6016
# Epoch 00016: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 333s 1s/step - monet_gen_loss: 2.7007 - photo_gen_loss: 2.7790 - monet_disc_loss: 0.6332 - photo_disc_loss: 0.6009
# Epoch 17/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.6960 - photo_gen_loss: 2.7753 - monet_disc_loss: 0.6359 - photo_disc_loss: 0.6104
# Epoch 00017: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 330s 1s/step - monet_gen_loss: 2.6956 - photo_gen_loss: 2.7732 - monet_disc_loss: 0.6360 - photo_disc_loss: 0.6103
# Epoch 18/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.6874 - photo_gen_loss: 2.7550 - monet_disc_loss: 0.6304 - photo_disc_loss: 0.6148
# Epoch 00018: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 329s 1s/step - monet_gen_loss: 2.6879 - photo_gen_loss: 2.7531 - monet_disc_loss: 0.6304 - photo_disc_loss: 0.6151
# Epoch 19/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.6399 - photo_gen_loss: 2.7282 - monet_disc_loss: 0.6391 - photo_disc_loss: 0.6166
# Epoch 00019: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 324s 1s/step - monet_gen_loss: 2.6394 - photo_gen_loss: 2.7263 - monet_disc_loss: 0.6386 - photo_disc_loss: 0.6159
# Epoch 20/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.6003 - photo_gen_loss: 2.6786 - monet_disc_loss: 0.6349 - photo_disc_loss: 0.6308
# Epoch 00020: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 328s 1s/step - monet_gen_loss: 2.6001 - photo_gen_loss: 2.6769 - monet_disc_loss: 0.6350 - photo_disc_loss: 0.6304
# Epoch 21/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5407 - photo_gen_loss: 2.6646 - monet_disc_loss: 0.6545 - photo_disc_loss: 0.6239
# Epoch 00021: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 331s 1s/step - monet_gen_loss: 2.5415 - photo_gen_loss: 2.6628 - monet_disc_loss: 0.6543 - photo_disc_loss: 0.6243
# Epoch 22/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5726 - photo_gen_loss: 2.6815 - monet_disc_loss: 0.6410 - photo_disc_loss: 0.6225
# Epoch 00022: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 335s 1s/step - monet_gen_loss: 2.5731 - photo_gen_loss: 2.6801 - monet_disc_loss: 0.6406 - photo_disc_loss: 0.6224
# Epoch 23/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5830 - photo_gen_loss: 2.6676 - monet_disc_loss: 0.6366 - photo_disc_loss: 0.6178
# Epoch 00023: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 338s 1s/step - monet_gen_loss: 2.5836 - photo_gen_loss: 2.6674 - monet_disc_loss: 0.6364 - photo_disc_loss: 0.6173
# Epoch 24/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5904 - photo_gen_loss: 2.6874 - monet_disc_loss: 0.6412 - photo_disc_loss: 0.6151
# Epoch 00024: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 345s 1s/step - monet_gen_loss: 2.5929 - photo_gen_loss: 2.6859 - monet_disc_loss: 0.6410 - photo_disc_loss: 0.6148
# Epoch 25/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5267 - photo_gen_loss: 2.6635 - monet_disc_loss: 0.6511 - photo_disc_loss: 0.6242
# Epoch 00025: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 347s 1s/step - monet_gen_loss: 2.5278 - photo_gen_loss: 2.6620 - monet_disc_loss: 0.6509 - photo_disc_loss: 0.6240

# %%
monet_generator = cycle_gan_model.m_gen

# %% [markdown]
# ## Visualize our Monet-esque photos

# %%
# Make a directory to save the images to
if not os.path.exists('dataoutput'):
        os.makedirs('dataoutput')

_, ax = plt.subplots(10, 2, figsize=(30, 30))

# Make sure to get the same images every time
d = 'imgdata/gan-getting-started/photo_jpg'
for i, img_path in enumerate(sorted(os.listdir(d))[0:10]):
    # Get the full path and load the image 
    img_path  = full_path = os.path.join(d, img_path)
    img = tf.io.read_file(img_path)
    img = decode_image(img)
    img = tf.expand_dims(
        img, axis=0
    )
    
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

    ax[i, 0].imshow(img)
    ax[i, 1].imshow(prediction)
    ax[i, 0].set_title("Input Photo")
    ax[i, 1].set_title("Monet-esque")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")

    # Save the image
    im = Image.fromarray(img)
    im.save("dataoutput/img{}.jpeg".format(i))
    pr = Image.fromarray(prediction)
    pr.save("dataoutput/pr{}.jpeg".format(i))

plt.show()

# %% [markdown]
# # Results

# %%
# Export training data to CSV
import csv
w = csv.writer(open("model_YOURNAMEHERE.csv", "w"))
w.writerow(['Label', 'Data'])
# Write the time as well
w.writerow(['time', time_callback.times])
for key, val in history.history.items():
    w.writerow([key, val])

# %%
# Try with a set of base images

# Make a directory to save the images to
if not os.path.exists('testoutput'):
        os.makedirs('testoutput')
        
_, ax = plt.subplots(10, 2, figsize=(30, 30))
d = 'imgtest'
for i, img_path in enumerate(os.listdir(d)):
    # Get the full path and load the image
    img_path  = full_path = os.path.join(d, img_path)
    img = tf.io.read_file(img_path)
    img = decode_image(img)
    img = tf.expand_dims(
        img, axis=0
    )

    # Get the prediction and alter the images
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

    # Output into a graph
    ax[i, 0].imshow(img)
    ax[i, 1].imshow(prediction)
    ax[i, 0].set_title("Input Photo")
    ax[i, 1].set_title("Monet-esque")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")

    # Save the image
    im = Image.fromarray(img)
    im.save("testoutput/imgtest{}.jpeg".format(i))
    pr = Image.fromarray(prediction)
    pr.save("testoutput/prtest{}.jpeg".format(i))

# %%
from google.colab import files

files.download('dataoutput')

# %%
files.download('model_YOURNAMEHERE.csv')
files.download('testoutput')
